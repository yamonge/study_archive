# %%
! pip install pandas

! pip install numpy

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
data = np.genfromtxt(r'./data/ratings.dat', delimiter='::', dtype=np.int64)
data
data.shape
# Out:
# (1000209, 4)

# %%
names = pd.read_csv(r'./data/NationalNames.csv', header=0, names=['id', 'name', 'year', 'sex', 'births'])
names.head(10)

names.count()

names.shape
# Out:
# (1825433, 5)

# %%
import os

# %%
print("현재 작업 경로:")
print(os.getcwd())

print("\n현재 폴더 내용:")
print(os.listdir())

names.tail(10)

total_birth = names.pivot_table('births', index='year', columns='sex', aggfunc=sum)

total_birth.head(10)

total_birth.plot(title='Total births by sex and year')
# Out:
# 현재 작업 경로:
# /home/pc/study_archive/ai/2026/08/18
#
# 현재 폴더 내용:
# ['Numpy01.ipynb', 'datatset.txt', 'data']
# /tmp/ipykernel_10703/3702720431.py:9: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_birth = names.pivot_table('births', index='year', columns='sex', aggfunc=sum)
# <Axes: title={'center': 'Total births by sex and year'}, xlabel='year'>
