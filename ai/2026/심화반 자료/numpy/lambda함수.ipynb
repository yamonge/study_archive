# %%
def plus_ten(x):
    return x + 10

# %%
plus_ten(5)
# Out:
# 15

# %%
lambda x: x + 10
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x: x + 10)(5)
# Out:
# 15

# %%
plus_ten = lambda x: x + 10
type(plus_ten)
# Out:
# function

# %%
plus_ten(44)
# Out:
# 54
