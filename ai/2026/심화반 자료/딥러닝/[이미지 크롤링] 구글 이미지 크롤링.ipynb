# %% [markdown]
# # 키워드 기반 이미지 크롤링 실습 (최소 100픽셀 필터링)
#
# ## 목표
# - 사용자가 입력한 키워드로 Google 이미지 검색에서 사진 데이터를 크롤링
# - 최소 한 변이 100픽셀 이상인 이미지만 다운로드
# - 저장 경로: `'./data/수집데이터/[검색어]'`
# - 전이학습 데이터셋 준비에 활용 가능
#
# ## 준비물
# - Python 3.x
# - 필요 라이브러리: `selenium`, `requests`, `beautifulsoup4`, `webdriver-manager`, `Pillow`
# - 설치 명령어: `pip install selenium requests beautifulsoup4 webdriver-manager Pillow`
# - Chrome 브라우저 설치
#
# ## 주의사항
# - Google의 빈번한 요청 차단 가능성 있음 (대기 시간 조정 필요)
# - 이미지 저작권 확인 후 학습 목적으로만 사용
#
# ## 실행 흐름
# 1. 환경 설정
# 2. 다운로드 함수 정의 (크기 필터링 포함)
# 3. 크롤링 함수 정의
# 4. 실행 및 다운로드

# %% [markdown]
# ## 1. 환경 설정

# %%
# !pip install webdriver_manager selenium beautifulsoup4 pillow

# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from PIL import Image
import io

# 필요 라이브러리 확인
print('환경 설정 완료!')
# Out:
# 환경 설정 완료!

# %% [markdown]
# ## 2. 다운로드 함수 정의
#
# - `create_download_folder`: `'./data/수집데이터/[검색어]'` 폴더 생성
# - `is_image_large_enough`: 이미지 크기 확인 (최소 100픽셀)
# - `download_image`: 이미지 다운로드 (크기 필터링 적용)

# %%
# 다운로드 폴더 생성 함수
def create_download_folder(keyword):
    base_path = './data/수집데이터'
    folder_name = os.path.join(base_path, keyword)
    if not os.path.exists(folder_name):
        os.makedirs(folder_name, exist_ok=True)  # 상위 폴더도 생성
    return folder_name

# 이미지 크기 확인 함수
def is_image_large_enough(img_data, min_size=100):
    try:
        img = Image.open(io.BytesIO(img_data))
        width, height = img.size
        return width >= min_size or height >= min_size
    except Exception as e:
        print(f"이미지 크기 확인 오류: {str(e)}")
        return False

# 이미지 다운로드 함수 (크기 필터링 포함)
def download_image(img_url, folder, img_name):
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(img_url, headers=headers, stream=True, timeout=10)
        if response.status_code == 200:
            img_data = response.content
            if is_image_large_enough(img_data):
                file_path = os.path.join(folder, img_name)
                with open(file_path, 'wb') as f:
                    f.write(img_data)
                print(f"다운로드 완료: {file_path}")
                return True
            else:
                print(f"이미지 크기 부족 (100픽셀 미만): {img_url}")
                return False
        else:
            print(f"다운로드 실패: {img_url} (상태 코드: {response.status_code})")
            return False
    except Exception as e:
        print(f"오류 발생: {img_url} - {str(e)}")
        return False

print('다운로드 함수 정의 완료!')
# Out:
# 다운로드 함수 정의 완료!

# %% [markdown]
# ## 3. 크롤링 함수 정의
#
# - `crawl_images`: Google 이미지 검색을 크롤링하고 이미지 다운로드
# - 최소 100픽셀 이상인 이미지만 저장

# %%
# Google 이미지 검색 크롤링 함수
def crawl_images(keyword, max_images=10):
    # Chrome 드라이버 설정
    options = webdriver.ChromeOptions()
    # options.add_argument('--headless')  # 브라우저 창 없이 실행
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    # Google 이미지 검색 URL
    search_url = f"https://www.google.com/search?q={keyword}&tbm=isch"
    driver.get(search_url)
    time.sleep(2)  # 페이지 로드 대기

    # 스크롤하여 더 많은 이미지 로드
    for _ in range(5):  # 5번 스크롤 (더 많은 이미지 확보)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)

    # 페이지 소스 가져오기
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    img_tags = soup.find_all('img')

    # 다운로드 폴더 생성
    download_folder = create_download_folder(keyword)
    downloaded_count = 0

    # 이미지 URL 추출 및 다운로드
    for idx, img in enumerate(img_tags):
        if downloaded_count >= max_images:
            break
        img_url = img.get('src') or img.get('data-src')
        if img_url and img_url.startswith('http'):
            img_name = f"{keyword}_{downloaded_count+1}.jpg"
            if download_image(img_url, download_folder, img_name):
                downloaded_count += 1

    driver.quit()
    print(f"총 {downloaded_count}개의 이미지를 다운로드했습니다.")

print('크롤링 함수 정의 완료!')
# Out:
# 크롤링 함수 정의 완료!

# %% [markdown]
# ## 4. 실행 및 다운로드
#
# - 키워드와 다운로드할 이미지 수를 입력하세요.
# - 예: 'puppy', 5 입력 시 `'./data/수집데이터/puppy'`에 최소 100픽셀 이상인 이미지 5장 다운로드

# %%
# 사용자 입력 및 크롤링 실행
keyword = input("검색할 키워드를 입력하세요: ")
max_images = int(input("다운로드할 최대 이미지 수를 입력하세요 (기본값 10): ") or 10)
crawl_images(keyword, max_images)
# Out:
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQR6j-7QGKKFPJZrlUTLXW4yl73NlzMVN5ImBSHeKn_orwzIaVnHuBfnrId&s
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1CVHnFqCVjIi2txccQIuVJj5u_qriKYWLsDX7hrmTSzHITsyHM8b6Z1vw&s
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT_hpKn9WllnrI4yMzy4pp1B_h8Li9jx-jvITJhZTIejz8tnXATd_avqE0d&s
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQqJW5iH3dqyJGDmmu8aSur8vYnAeVrRYX9b4-YEpwOObGpjQuPb4713tSj&s
# 이미지 크기 확인 오류: cannot identify image file <_io.BytesIO object at 0x000002BCCB5EFE20>
# 이미지 크기 부족 (100픽셀 미만): https://fonts.gstatic.com/s/i/productlogos/googleg/v6/24px.svg
# 다운로드 완료: ./data/수집데이터\사람\사람_1.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_2.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_3.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_4.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_5.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_6.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_7.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_8.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_9.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_10.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_11.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_12.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_13.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_14.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_15.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSC5vVlHli1OEo5goSZis-mtSBoucTUzr54ioS2ARpHZLvXAUMzsICV&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRq6FVUmCT3qlSiDclaZhytweeNseYuG4AsBL_awX2d0vfKQs5ODCbQ&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT1qB5PdYOya3pg-zzheRuDZAzB6CLLb6uP2n4RYCAeJ1GzXKHgn7t0&s=0
# 다운로드 완료: ./data/수집데이터\사람\사람_16.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_17.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_18.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_19.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_20.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_21.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_22.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_23.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_24.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_25.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_26.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_27.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_28.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_29.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_30.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_31.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_32.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_33.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_34.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_35.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_36.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_37.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_38.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_39.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTUXYo7x6ltrrsVLB27AB4kDN5jzhycC0shNZZSNU8IvcRJgjXNFc8S&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSwNCeyC8yQm4bUX2OXQxrovpbC-1Ut3reesBObe3UE7lHZnC0BjtBM&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGc2b2teVfyMIOgo8x6WQxSLNLi-VbBiso3Gl5KkDsCDVJg-uCX16w&s=0
# 다운로드 완료: ./data/수집데이터\사람\사람_40.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_41.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_42.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_43.jpg
# 다운로드 완료: ./data/수집데이터\사람\사람_44.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://hypebeast.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_45.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.yna.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_46.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://kr.freepik.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_47.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://livejapan.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_48.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.shutterstock.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_49.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.khan.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_50.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.chosun.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_51.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=http://esaram.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_52.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://namu.wiki&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_53.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.pngegg.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_54.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.hankyung.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_55.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.dailian.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_56.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.urbanbrush.net&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_57.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://hypebeast.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_58.jpg
# 다운로드 실패: https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.chegim.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL (상태 코드: 404)
# 다운로드 완료: ./data/수집데이터\사람\사람_59.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://m.gettyimagesbank.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_60.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.industrynews.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_61.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.crowdpic.net&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_62.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.dongascience.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_63.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.tossbank.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_64.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.youthdaily.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGc2b2teVfyMIOgo8x6WQxSLNLi-VbBiso3Gl5KkDsCDVJg-uCX16w&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDrXc9DklFd0zsws235NLgPGHKzh3THmvz02t-H0cqDoH9PE4Tdnx_&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRBFsXkexKfiGeKhwYJfm_Y9RkaVR-Yt3Xyqs4NVTa&s=0
# 다운로드 완료: ./data/수집데이터\사람\사람_65.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.fitpetmall.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_66.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://meditationlife.org&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_67.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://news.hidoc.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_68.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.istockphoto.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_69.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.donga.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_70.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://kbthink.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_71.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.joongang.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_72.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.youtube.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_73.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://ktxmagazine.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_74.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://news.kbs.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_75.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.knowhow.or.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_76.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.hani.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_77.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.mindgil.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_78.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://kr.pinterest.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_79.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://x.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_80.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://mobile.newsis.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_81.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://kor.pngtree.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_82.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://kormedi.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_83.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://blog.hanabank.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_84.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://kr.123rf.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_85.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.pngwing.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_86.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.mk.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_87.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://free3d.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_88.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=http://www.seoulilbo.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS_F9yaa2z8CzHMuJblRW2rFl0XFWv_q8bd7mSpC6tOVaqcTN4uo72u&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0WMsJHsTuPGXTxODaq7m7qRQC4gtlaOOAgoBMcAHH&s=0
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcROWPttyOqy9IrzjfGO9eDQL3jBZvPFwENNrrmGWFoJ&s=0
# 다운로드 완료: ./data/수집데이터\사람\사람_89.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.imaeil.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_90.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn2.gstatic.com/faviconV2?url=https://saramfoundation.org&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_91.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.munhwa.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_92.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.nocutnews.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_93.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.venturesquare.net&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_94.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.womansense.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_95.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn1.gstatic.com/faviconV2?url=https://ko.wikipedia.org&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_96.jpg
# 다운로드 실패: https://encrypted-tbn0.gstatic.com/faviconV2?url=https://cine21.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL (상태 코드: 404)
# 다운로드 완료: ./data/수집데이터\사람\사람_97.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.sisain.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_98.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn3.gstatic.com/faviconV2?url=https://tvn.cjenm.com&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_99.jpg
# 이미지 크기 부족 (100픽셀 미만): https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.sentv.co.kr&client=IMAGE_SEARCH&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL
# 다운로드 완료: ./data/수집데이터\사람\사람_100.jpg
# 총 100개의 이미지를 다운로드했습니다.
